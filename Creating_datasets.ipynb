# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import requests
import concurrent.futures
import time

# %% [markdown]
# # Dataset Preparation for Sentence Transformers

# %% [markdown]
# ## Part 1: Using raw CV text without making any updates or changes with language models

# %% [markdown]
# ### Candidate Data

# %%
# Reading the candidate data and looking at its shape

df_candidate = pd.read_csv("DatasetwithExperiences.csv")
df_candidate.shape
# Out:
# (95817, 11)

# %%
# Looking at the column names
df_candidate.columns
# Out:
# Index(['Id_candidate', 'name', 'fileName', 'nationality', 'permis', 'address',
#        'experiences', 'text', 'gender', 'postcode', 'jobTitle'],
#       dtype='object')

# %%
# Are there any duplicate entries? are there any duplicates in the id_candidate column?

df_candidate['Id_candidate'].is_unique
# Out:
# False

# %%
# there are duplicate candidates. Lets's get rid of them. 
df_candidate.drop_duplicates(subset=['Id_candidate'], keep='first', inplace=True)

# %%
# Shape of the candidate data after dropping the duplicates

df_candidate.shape
# Out:
# (78723, 11)

# %%
df_candidate['text'].isnull().sum()
# Out:
# 307

# %% [markdown]
# ### Vacancies Data

# %%
# Reading the vacancies dataset and looking at the shape

df_vac = pd.read_csv('vacancies.csv', sep=';')
df_vac.shape
# Out:
# (13204, 16)

# %%
df_vac.head(3)
# Out:
#       Id                                             Titre  \
# 0      4                             Candidature spontanée
# 1  13983  Commercial B to B itinérant (H/F) - Montbéliard
# 2  13982           Responsable d'Agence (H/F) - Vitrolles
#
#                        Région Département        Ville  Fonction  \
# 0                         NaN         NaN          NaN       NaN
# 1               Franche Comté          25  Montbéliard  Commerce
# 2  Provence Alpes Côte d'Azur          13    Vitrolles  Commerce
#
#   Date d'activation Type de poste Type de formation  \
# 0        20/06/2006           NaN               NaN
# 1        17/04/2024           CDI         BAC+2/BTS
# 2        16/04/2024           CDI         BAC+2/BTS
#
#    Salaire min (euro brut annuel)  Salaire max (euro brut annuel)  \
# 0                             NaN                             NaN
# 1                         27000.0                         32000.0
# 2                         24000.0                         35000.0
#
#                                       Profil attendu  \
# 0                                                NaN
# 1  Issu-e d'une formation commerciale, vous dispo...
# 2  Vous avez une première expérience réussie, not...
#
#                       Expérience  \
# 0                            NaN
# 1  Expérimenté/Pas de management
# 2       Manager/Gestion d'équipe
#
#                                Descriptif de l'offre Actif Archivé
# 0                                                NaN   Oui     Non
# 1  Commercial BtoB itinérant h/f - CDI  Au sein d...   Oui     Non
# 2  Responsable d'Agence h/f - CDI  Grâce à votre ...   Oui     Non

# %%
# getting rid of the first entry
df_vac = df_vac.iloc[1:].reset_index(drop=True)
df_vac.shape
# Out:
# (13203, 16)

# %%
# are there any duplicates in the id_vacancy?

df_vac['Id'].is_unique

# no duplicates
# Out:
# True

# %%
# Since we are preparing data for a sentence transformer that accepts sentence pairs as inputs, we need to combine all the information about the vacancy into a single unified piece of text which will be treated as a "sentence". 

df_vac_textual = pd.DataFrame(columns = ['Id_vacancy', 'vacancy_text'])

df_vac_textual['Id_vacancy'] = df_vac['Id'].unique()

df_vac_textual.shape
# Out:
# (13203, 2)

# %%
for i in range(df_vac_textual.shape[0]):
    details = ""
    details += "Titre: " + str(df_vac['Titre'][i]) if pd.notnull(df_vac['Titre'][i]) else "Titre: " + "" 
    details += "\nFonction: " + str(df_vac['Fonction'][i]) if pd.notnull(df_vac['Fonction'][i]) else "\nFonction: " + ""
    details += "\nVille et Region: " + (str(df_vac['Ville'][i]) if pd.notnull(df_vac['Ville'][i]) else "") + ", " + (str(df_vac['Région'][i]) if pd.notnull(df_vac['Région'][i]) else "")
    details += "\nType de poste: " + str(df_vac['Type de poste'][i]) if pd.notnull(df_vac['Type de poste'][i]) else "\nType de poste: " + ""
    details += "\nDescriptif de l'offre: " + str(df_vac["Descriptif de l'offre"][i]) if pd.notnull(df_vac["Descriptif de l'offre"][i]) else "\nDescriptif de l'offre: "
    details += "\nType de formation requise: " + str(df_vac['Type de formation'][i]) if pd.notnull(df_vac['Type de formation'][i]) else "\nType de formation requise: "
    details += "\nProfil attendu: " + str(df_vac['Profil attendu'][i]) if pd.notnull(df_vac['Profil attendu'][i]) else "\nProfil attendu: "

    df_vac_textual.loc[i, 'vacancy_text'] = details

# %%
df_vac_textual.shape
# Out:
# (13203, 2)

# %%
df_vac_textual.isnull().sum()
# Out:
# Id_vacancy      0
# vacancy_text    0
# dtype: int64

# %%
#df_vac_textual.to_csv('vacancies_textual.csv')

# %% [markdown]
# ### Applications Data

# %%
# Reading the two application csv files and viewing their shape

df_app_pos = pd.read_csv("applications_positive.csv", sep=';')
df_app_neg = pd.read_csv("applications_negative.csv", sep=';')

df_app_pos.shape, df_app_neg.shape
# Out:
# C:\Users\Sinjini\AppData\Local\Temp\ipykernel_744\383347155.py:4: DtypeWarning: Columns (7,9,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_app_neg = pd.read_csv("applications_negative.csv", sep=';')
# ((34917, 15), (65716, 15))

# %%
# column names of both the datasets

print(df_app_pos.columns)
print(df_app_neg.columns)

# same column names
# Out:
# Index(['Id_application', 'Date', 'Id_candidate', 'Id_vacancy', 'Civilité',
#        'Ville', 'status', 'Motif de refus', 'Métier', 'Tranche d'age',
#        'Type de contrat', 'Prétentions salariales mensuelles fixe net',
#        'Permis de conduire', 'Mobilité', 'Code postal'],
#       dtype='object')
# Index(['Id_application', 'Date', 'Id_candidate', 'Id_vacancy', 'Civilité',
#        'Ville', 'status', 'Motif de refus', 'Métier', 'Tranche d'age',
#        'Type de contrat', 'Prétentions salariales mensuelles fixe net',
#        'Permis de conduire', 'Mobilité', 'Code postal'],
#       dtype='object')

# %%
# 'status' values for both the datasets

print(df_app_pos['status'].value_counts())
print("-------------------------------------------------------------")
print(df_app_neg['status'].value_counts())
# Out:
# status
# Poste pourvu    32657
# Embauche         2260
# Name: count, dtype: int64
# -------------------------------------------------------------
# status
# Négatif + 2jrs       43123
# Négatif              12476
# Négatif + 5jrs        2606
# Neg sans msg          2191
# NET+ 3jrs             1035
# NET                    848
# NET Savoir Faire       759
# NET Localisation       624
# NET Rému               610
# NAE                    435
# NAE +5jrs              299
# No news                242
# NET Savoir Etre        171
# NET Cond. Travail      134
# Vivier                  97
# NAE Vivier              52
# Vivier + 2jrs           14
# Name: count, dtype: int64

# %%
# Merging "app_pos" and "app_neg" to form a single applications dataset

df_app = pd.concat([df_app_pos, df_app_neg], ignore_index=True)
df_app.shape
# Out:
# (100633, 15)

# %%
df_app.isnull().sum()
# Out:
# Id_application                                     0
# Date                                               0
# Id_candidate                                       0
# Id_vacancy                                         0
# Civilité                                       15976
# Ville                                           9284
# status                                             0
# Motif de refus                                 99551
# Métier                                          1161
# Tranche d'age                                  99396
# Type de contrat                               100632
# Prétentions salariales mensuelles fixe net     73782
# Permis de conduire                             68965
# Mobilité                                      100442
# Code postal                                    13357
# dtype: int64

# %%
df_app['Mobilité'].value_counts()
# Out:
# Mobilité
# Ile-de-france                                          63
# Haute-Normandie                                        19
# Pays de la Loire                                       19
# Internationale , Nationale                             18
# Nord pas de Calais                                     10
# Nationale                                               7
# Rhônes Alpes                                            7
# Bourgogne                                               5
# Internationale , Rhônes Alpes                           5
# Basse Normandie                                         4
# Champagne Ardenne                                       4
# Picardie                                                3
# Midi Pyrénées                                           3
# Bretagne                                                3
# Internationale                                          3
# Aquitaine                                               3
# Aquitaine , Poitou Charentes                            2
# Centre                                                  2
# Provence Alpes Côte d'Azur                              2
# Internationale , Nationale , Ile-de-france , Locale     2
# Aquitaine , Ile-de-france                               2
# Ile-de-france , Picardie                                1
# Bretagne , Pays de la Loire                             1
# Languedoc Roussillon                                    1
# Locale                                                  1
# Lorraine                                                1
# Name: count, dtype: int64

# %% [markdown]
# The Mobilite column has many missing values. However, it is an important feature as it contains the
# candidate’s desired job location. The values that are not missing are regions, not cities.
# The Ville column (candidate’scurrent city) has negligible missing values. Hence, a new column 'Region'
#  should be created by mapping each Ville to its corresponding region using the
#  Wikidata API. The missing Mobilite values could then be filled with this new
#  Region column. This means that if the candidate has specifically mentioned
#  their wish of job location, we would take that into account, otherwise, we
#  will take into account the region where the candidate currently lives.

# %%
# Creating a new region column first and initializing it with None. 

df_app['Region'] = None

# %%
def get_entity_data(qid):
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{qid}.json"
    response = requests.get(url)
    response.raise_for_status()
    return response.json()['entities'][qid]

def get_instance_of_ids(entity):
    claims = entity.get('claims', {})
    if 'P31' not in claims:
        return []
    return [claim['mainsnak']['datavalue']['value']['id'] for claim in claims['P31']]

def find_region(qid, visited=None):
    if visited is None:
        visited = set()
    if qid in visited:
        return None
    visited.add(qid)

    entity = get_entity_data(qid)
    instance_of = get_instance_of_ids(entity)

    # If this entity is a French region (Q36784), return it
    if "Q36784" in instance_of:
        return entity['labels']['fr']['value']

    # Otherwise, go up the P131 chain
    p131_claims = entity.get('claims', {}).get('P131')
    if not p131_claims:
        return None

    for claim in p131_claims:
        parent_qid = claim['mainsnak']['datavalue']['value']['id']
        region = find_region(parent_qid, visited)
        if region:
            return region

    return None

def get_city_region(city_name):
    # Step 1: Search for the city
    search_url = "https://www.wikidata.org/w/api.php"
    search_params = {
        "action": "wbsearchentities",
        "search": city_name,
        "language": "en",
        "format": "json",
        "limit": 1
    }
    search_response = requests.get(search_url, params=search_params).json()
    if not search_response['search']:
        return f"No results found for {city_name}"
    entity_id = search_response['search'][0]['id']

    # Step 2: Walk the hierarchy to find region
    region = find_region(entity_id)
    return region or f"No region found for {city_name}"

# %%
# Step 1: Deduplicate cities
unique_cities = df_app['Ville'].dropna().unique()

# Step 2: Define thread-safe wrapper
def fetch_region(city):
    try:
        region = get_city_region(city)
        print(f"{city}: {region}")
        return (city, region)
    except Exception as e:
        print(f"Exception for {city}: {e}")
        return (city, None)

# Step 3: Fetch in parallel
city_region_map = {}
start_time = time.time()

with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    results = executor.map(fetch_region, unique_cities)
    for city, region in results:
        city_region_map[city] = region

print(f"\nFetched regions for {len(city_region_map)} unique cities in {round(time.time() - start_time, 2)} seconds.")


# Step 4: Apply the map back to DataFrame (only where Region is null)
df_app['Region'] = df_app.apply(
    lambda row: city_region_map.get(row['Ville']) if pd.isnull(row['Region']) and pd.notnull(row['Ville']) else row['Region'],
    axis=1
)
# Out:
# ST OUEN EN BELIN: No results found for ST OUEN EN BELIN
# Le Mesle: No results found for Le Mesle
# Alençon: Normandie
# BOISSY SAINT LEGER: Île-de-France
# salon de provence: Provence-Alpes-Côte d'Azur
# Plouhinec: Bretagne
# AUZOUER EN TOURAINE: Centre-Val de Loire
# orléans: Centre-Val de Loire
# NARBONNE: Occitanie
# Marseille: Provence-Alpes-Côte d'Azur
# croix: Hauts-de-France
# REIMS: Grand Est
# Lanildut: Bretagne
# Halluin : Hauts-de-France
# SAINT-Fons: Auvergne-Rhône-Alpes
# belin-beliet: Nouvelle-Aquitaine
# Bondy: Île-de-France
# WATTRELOS: Hauts-de-France
# MONDEVILLE: Normandie
# CHALONS-EN-CHAMPAGNE: Grand Est
# saint cloud: Île-de-France
# Leuville sur orge: Île-de-France
# Argenteuil: Île-de-France
# Pessac: Nouvelle-Aquitaine
# Vallangoujard: Île-de-France
# RUEIL MALMAISON: Île-de-France
# Paris 19e: Île-de-France
# BOIS-GUILLAUME: Normandie
# ATTICHY: Hauts-de-France
# BOBIGNY: Île-de-France
# Choisy-Le-Roi: Île-de-France
# Velaux: Provence-Alpes-Côte d'Azur
# SURESNES: Île-de-France
# TOURCOING: Hauts-de-France
# ROSNY SUR SEINE: Île-de-France
# la celle st cloud: Île-de-France
# goussainville: Île-de-France
# MERIGNAC: Nouvelle-Aquitaine
# St OUEN L'AUMONE: Île-de-France
# RENNES: Bretagne
# miribel: Auvergne-Rhône-Alpes
# Saint-Denis : La Réunion
# Roissy-En-Brie: Île-de-France
# Neuville-en-Ferrain: Hauts-de-France
# Asnières-sur-seine: Île-de-France
# saint dié: Grand Est
# Mouvaux: Hauts-de-France
# Bobigny: Île-de-France
# Le Haillan: Nouvelle-Aquitaine
# PARIS: Île-de-France
# Vienne: Auvergne-Rhône-Alpes
# LANCON PROVENCE: Provence-Alpes-Côte d'Azur
# MONTGERON: Île-de-France
# Ozoir-la-Ferrière: Île-de-France
# Lille: Hauts-de-France
# FONTCOUVERTE: Occitanie
# Villeparisis: Île-de-FranceFameck: Grand Est
#
# Princé: No region found for Princé
# Colombes: Île-de-France
# Dissay: Nouvelle-Aquitaine
# Chassal: No region found for Chassal
# Monein: Aquitaine
# CHOISY LE ROI: Île-de-France
# ROQUEBRUNE-SUR-ARGENS: Provence-Alpes-Côte d'Azur
# Valence : Auvergne-Rhône-Alpes
# AIZENAY: Pays de la Loire
# halluin: Hauts-de-France
# Sceaux: Île-de-France
# Choisy-le-Roi: Île-de-France
# hericourt: Bourgogne-Franche-Comté
# Saint Avit Saint Nazaire: Nouvelle-Aquitaine
# seloncourt: Bourgogne-Franche-Comté
# Portugal: No region found for Portugal
# massongy: Auvergne-Rhône-Alpes
# Guiclan: Bretagne
# Berre-l’Étang : Provence-Alpes-Côte d'Azur
# Echirolles: Auvergne-Rhône-Alpes
# biron: No region found for biron
# GAN: No region found for GAN
# Ligugé: Nouvelle-Aquitaine
# La Madeleine: Hauts-de-France
# ferolles: Centre-Val de Loire
# Saint-Léger-du-Bourg-Denis: Normandie
# Bordeaux: Nouvelle-Aquitaine
# MOUGINS: Provence-Alpes-Côte d'Azur
# VILLEMOMBLE, 93250, FR: No results found for VILLEMOMBLE, 93250, FR
# Nice: Provence-Alpes-Côte d'Azur
# SERVON: Île-de-France
# Agen: Nouvelle-Aquitaine
# Marmagne : Bourgogne-Franche-Comté
# Angers: Pays de la Loire
# VENISSIEUX: Auvergne-Rhône-Alpes
# Champigny sur Marne : Île-de-France
# Castelnau-le-Lez: Occitanie
# CARPENTRAS: Provence-Alpes-Côte d'Azur
# Jouars-Pontchartrain: Île-de-France
# Paris 14e: Île-de-France
# Bessines/Gartempe: No results found for Bessines/Gartempe
# Quinçay: Nouvelle-Aquitaine
# Sèvres-Auxaumont: No results found for Sèvres-Auxaumont
# SENS: Bourgogne-Franche-Comté
# France: No region found for France
# tremouilles: Occitanie
# Elbeuf: Normandie
# Bécherel: Bretagne
# Vigneux-sur-Seine: Île-de-France
# Berteaucourt les thennes : Hauts-de-France
# Sain bel : Auvergne-Rhône-Alpes
# Déols: Centre-Val de Loire
# Magland: Auvergne-Rhône-AlpesORLEANS: Centre-Val de Loire
#
# les milles: Provence-Alpes-Côte d'Azur
# Fontenay: Normandie
# Magnet: Auvergne-Rhône-Alpes
# LAHONCE: Aquitaine
# Colomiers: Occitanie
# Saint-Étienne-du-Rouvray : Normandie
# MONTBAZON: Centre-Val de Loire
# clamart: Île-de-France
# saint just la pendue: Auvergne-Rhône-Alpes
# ennery: Île-de-France
# Paris 13e: Île-de-France
# Bayonne: AquitaineComblanchien: Bourgogne-Franche-Comté
#
# ST HERBLAIN: Pays de la Loire
# Saint-Marcel: Centre-Val de Loire
# Le Plessis Trevise : Île-de-France
# Survilliers: Île-de-France
# Gasny: Normandie
# Viry-Châtillon: Île-de-France
# GRANDCHAMP-DES-FONTAINES: Pays de la Loire
# CAHAGNES: Normandie
# SAINTE CROIX: No region found for SAINTE CROIX
# elbeuf: Normandie
# MONTIGNY LES METZ: Grand Est
# Elne: Languedoc-Roussillon
# Saint-Cyr-sur-Loire: Centre-Val de Loire
# Lintot: Normandie
# GASSIN: Provence-Alpes-Côte d'Azur
# Pont du Château: Auvergne-Rhône-Alpes
# Sainte-Féréole: Nouvelle-Aquitaine
# Belcodène : Provence-Alpes-Côte d'Azur
# Mandres-les- Roses: No results found for Mandres-les- Roses
# Heyrieux: Auvergne-Rhône-Alpes
# Rouvroy : Hauts-de-France
# Chaumont: Grand Est
# OLIVET: Centre-Val de Loire
# Jugon les lacs: Bretagne
# Tarnos: Nouvelle-Aquitaine
# Port Jérôme sur Seine: Normandie
# GAUJAC: OccitaniePerrier: No region found for Perrier
#
# Criquebeuf-sur-Seine: Normandie
# Monéteau: Bourgogne-Franche-Comté
# ERCE PRES LIFFRE: Bretagne
# Brax: Occitanie
# Saint-Quentin : Hauts-de-France
# Antibes: Provence-Alpes-Côte d'Azur
# Sauzet: Auvergne-Rhône-Alpes
# PODENSAC: Nouvelle-Aquitaine
# Vougy: Auvergne-Rhône-Alpes
# Vern-Sur-Seiche: Bretagne
# Coulounieix-Chamiers: Nouvelle-Aquitaine
# Beaumont du Périgord : Nouvelle-Aquitaine
# AUROS: Nouvelle-Aquitaine
# Corbas: Auvergne-Rhône-Alpes
# Lisses: Île-de-France
# Varangéville: Grand Est
# La Begude de Mazenc : Auvergne-Rhône-Alpes
# Puteaux: Île-de-France
# Chelles: Île-de-France
# Calais : No region found for Calais
# LES ESSARTS EN BOCAGE: Pays de la Loire
# Le Cellier: Pays de la Loire
# Villeneuve-d'Ascq: Hauts-de-France
# ORVAULT: Pays de la Loire
# Moulins-sur-Yèvre: Centre-Val de Loire
# Aiton: Auvergne-Rhône-Alpes
# Sannois: Île-de-France
# Thizy: Bourgogne-Franche-Comté
# St cyr l'école : Île-de-France
# SAINT AVERTIN: Centre-Val de Loire
# Saint Michel: Hauts-de-France
# Veyrac: Nouvelle-Aquitaine
# Violaines: Hauts-de-France
# Marcq en Baroeul: Hauts-de-France
# Meaux: Île-de-France
# mazerolles: Nouvelle-Aquitaine
# Montlhéry: Île-de-France
# Sailly-au-Bois: Hauts-de-France
# CHALON SUR SAONE: Bourgogne-Franche-Comté
# Dammartin en Goelle: No results found for Dammartin en Goelle
# Migennes: Bourgogne-Franche-Comté
# LIMOGES: Nouvelle-Aquitaine
# Joué lés tours: Centre-Val de Loire
# Saint Eloi: Auvergne-Rhône-Alpes
# Bègles: Nouvelle-Aquitaine
# Bièvres: Île-de-France
# Finhan: Occitanie
# string:FRAISANS: No results found for string:FRAISANS
# Genouilly: Centre-Val de Loire
# Pontchateau : Pays de la Loire
# Nointel: Hauts-de-France
# Le havre: Normandie
# Remilly sur tille : Bourgogne-Franche-Comté
# Châteaubourg: Bretagne
# Lapeyrousse fossat : No results found for Lapeyrousse fossat
# Le noyer en ouche : Normandie
# Béziers: Occitanie
# SOTTEVILLELESROUEN: No results found for SOTTEVILLELESROUEN
# Vigneux sur Seine: Île-de-France
# Saint-Priest: Auvergne-Rhône-Alpes
# Servian: Occitanie
# la teste de buch: Nouvelle-Aquitaine
# Montreuil-le-gast: Bretagne
# Pineuilh: Nouvelle-Aquitaine
# Arthon: Centre-Val de Loire
# Pointe-à-Pitre: Guadeloupe
# Sainte-Anne: Martinique
# Odratzheim : Grand Est
# ARGELES GAZOST: Occitanie
# Dambach-la-Ville: Grand Est
# PONTRIEUX: Bretagne
# AMBAZAC: Nouvelle-Aquitaine
# PREMILHAT: Auvergne-Rhône-Alpes
# Saint-Max - (54130): No results found for Saint-Max - (54130)
# Tréméven: Bretagne
# EBERBACH-Gundershoffen: No results found for EBERBACH-Gundershoffen
# tourtour: Provence-Alpes-Côte d'Azur
# Marcillat-en-Combraille: Auvergne-Rhône-Alpes
# domerat: Auvergne-Rhône-Alpes
# COSNE D'ALLIER: Auvergne-Rhône-Alpes
# Corbières que : No results found for Corbières que
# PONTACQ: Aquitaine
# Illkirch : Grand Est
# Le GRAND-QUEVILLY: Normandie
# SANGUINET: Nouvelle-Aquitaine
# La petite Ariana: No results found for La petite Ariana
# st savournin: Provence-Alpes-Côte d'Azur
# CHARENTON DU CHER: Centre-Val de Loire
# saint étienne : Auvergne-Rhône-Alpes
# HAYANGE: Grand Est
# Cestas : Nouvelle-Aquitaine
# BORDEAUX (033): No results found for BORDEAUX (033)
# Kertzfeld: Grand Est
# IGE: No region found for IGE
# CAUJAC: Occitanie
# CHEVAIGNE: Bretagne
# Cubnezais : Nouvelle-Aquitaine
# VIRIAT: Auvergne-Rhône-Alpes
# Villemur sur Tarn : Occitanie
# Poumarous: Occitanie
# Cormoranche sur Saône: Auvergne-Rhône-Alpes
# St jean de braye: No results found for St jean de braye
# Cinq-Mars-La-Pile: Centre-Val de Loire
# Épeigné-sur-Dême: Centre-Val de Loire
# Bischoffsheim: Grand Est
# PARIS 19: No region found for PARIS 19
# le haillan: Nouvelle-Aquitaine
# CESSIEU: Auvergne-Rhône-Alpes
# Treilles: Occitanie
# Belleville-en-Beaujolais: Auvergne-Rhône-Alpes
# CHARENTILLY: Centre-Val de Loire
# HOMMES: Centre-Val de Loire
# Martigné ferchaud: Bretagne
# PONT-A-MOUSSON: Grand Est
# Guillestre: Provence-Alpes-Côte d'Azur
# Saint-Pont: Auvergne-Rhône-Alpes
# HOMÉCOURT: Grand Est
# Septèmes- les- Vallons: No results found for Septèmes- les- Vallons
# Rungis île de France : No results found for Rungis île de France
# 68310 - WITTELSHEIM: No results found for 68310 - WITTELSHEIM
# Réalcamp: Normandie
# PONT-SCORFF: Bretagne
# Noyal sous bazouges: Bretagne
# 69580 - SATHONAY CAMP: No results found for 69580 - SATHONAY CAMP
# VILLEBOURG (37370): No results found for VILLEBOURG (37370)
# ST BABEL: No results found for ST BABEL
# Renwez: Grand Est
# Blanc Mesnil: Normandie
# Charnay Les Macon: Bourgogne-Franche-Comté
# Creuzier-le-vieux: Auvergne-Rhône-Alpes
# Dschang: No region found for Dschang
# Osny : Île-de-France
# Sillans-la-Cascade: Provence-Alpes-Côte d'Azur
# le grand-quevilly: Normandie
# tossiat: Auvergne-Rhône-Alpes
# JARVILLE LA MALGRANGE: Grand Est
# VILLEURBANNNE: No results found for VILLEURBANNNE
# AIX en Provence: Provence-Alpes-Côte d'Azur
# Villeurbanne (Lyon): No results found for Villeurbanne (Lyon)
# ST ETIENNE DU BOIS: No region found for ST ETIENNE DU BOIS
# Cairon: Normandie
# mazieres de touraine: Centre-Val de Loire
# MALICORNE: Auvergne-Rhône-Alpes
# Aire sur l’Adour: Nouvelle-Aquitaine
# Saint-Etienne-de-Chigny: Centre-Val de Loire
# Bron, FR: No results found for Bron, FR
# bischheim: Grand Est
# Seiches sur le loir : Pays de la Loire
# Mourouj : No results found for Mourouj
# Saint André de la Roche : Provence-Alpes-Côte d'Azur
# Rochefort en Yvelines: Île-de-France
# GOUSSAINVILLE : Île-de-France
# schiltigheim: Grand Est
# Saint-Just: Bretagne
# Sainte-Colombe: Auvergne-Rhône-Alpes
# GIRAUMONT: Grand Est
# septeme: Auvergne-Rhône-Alpes
# EYJ EAUX: No results found for EYJ EAUX
# Les Touches: Pays de la Loire
# Saint-Méen-le-Grand: Bretagne
# Asnieres Sur Oise: Île-de-France
# Ablon sur seine : Île-de-France
# Chartres de bretagne: Bretagne
# Mondon: Bourgogne-Franche-Comté
# Gif sur Yvette: Île-de-France
# Nancy sur Cluses: Auvergne-Rhône-Alpes
# Monnetier mornex : Auvergne-Rhône-Alpes
# La teste: Nouvelle-Aquitaine
# Hérouville Saint Clair: Normandie
# Faucigny: Auvergne-Rhône-Alpes
# Aigrefeuille: Occitanie
# Blangy-le-Château : Normandie
# Angerville l’orcher: Normandie
# Ceyzériat: Auvergne-Rhône-Alpes
# Cluny: Bourgogne-Franche-Comté
# Longvic : Bourgogne-Franche-Comté
# Saint mesmin : Bourgogne-Franche-Comté
# Drambon: Bourgogne-Franche-Comté
# Cherbourg : Normandie
# Villenave D'Ornon: Nouvelle-Aquitaine
# PENNE-D'AGENAIS: Nouvelle-Aquitaine
# La Vèze: Bourgogne-Franche-Comté
# Villeneuve-le-roi: Île-de-France
# Saint Denis les bourg: Auvergne-Rhône-Alpes
# Marcheprime : Nouvelle-Aquitaine
# LA VILLE AU DAME : No results found for LA VILLE AU DAME
#  GRENOBLE: Auvergne-Rhône-Alpes
# Ambilly: Auvergne-Rhône-Alpes
# 94000 - CRETEIL: No results found for 94000 - CRETEIL
# Bosc-Hyons: Normandie
# Louvigné-de-Bais: Bretagne
# L ISLE D ABEAU: Auvergne-Rhône-Alpes
# SOEURDRES: Pays de la Loire
# aubergenville: Île-de-France
# Varennes sur allier: Auvergne-Rhône-Alpes
# St Jean de Niost: No results found for St Jean de Niost
# BISCHWILLER: Grand Est
# Saint Martin de crau: Provence-Alpes-Côte d'Azur
# Orgerus - (78910): No results found for Orgerus - (78910)
# Aiguefonde: Occitanie
# CHÂTEAU GONTIER: Pays de la Loire
# AUDENGE: Nouvelle-Aquitaine
# VENDENHEIM: Grand Est
# Annay : Hauts-de-France
# Granville : Normandie
# Le Barp : Nouvelle-Aquitaine
# Grisy-les-Plâtres: Île-de-France
# Ambronay: Auvergne-Rhône-Alpes
# Fès Maroc : No results found for Fès Maroc
# GRENADE: Occitanie
# LITTENHEIM: Grand Est
# Orme: No region found for Orme
# COURTILS: Normandie
# villeneuve d'Asque: No results found for villeneuve d'Asque
# Fuissé: Bourgogne-Franche-Comté
# Carnon plage : Occitanie
# Corseul: Bretagne
# Chailly en brie: Île-de-France
# Replonges : Auvergne-Rhône-Alpes
# Pipriac: Bretagne
# Challes: Pays de la Loire
# Rohan: No region found for Rohan
# Pompey: Grand Est
# Valmondois : Île-de-France
# EYBOULEUF: Nouvelle-Aquitaine
# Les Marines de Cogolin: Provence-Alpes-Côte d'Azur
# Saint-Pierre-en-Val: Normandie
# Pont Péan : Bretagne
# Savigny-le-Sec: Bourgogne-Franche-Comté
# Menville: Occitanie
# dieulouard: Grand Est
# servian: Occitanie
# Ducey: Normandie
# Martillac: Nouvelle-Aquitaine
# Tregueux: Bretagne
# Coulounieix Chamiers : Nouvelle-Aquitaine
# VILLEFRANCHE-SUR-SAONE: Auvergne-Rhône-Alpes
# Manziat : Auvergne-Rhône-Alpes
# Oppede : Provence-Alpes-Côte d'Azur
# MOULINEAUX : Normandie
# Montferrand-le-château: Bourgogne-Franche-Comté
# jury: Grand Est
# Gandrange : Grand Est
# Ainay le vieil: Centre-Val de Loire
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 20
#      18 with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
#      19     results = executor.map(fetch_region, unique_cities)
# ---> 20     for city, region in results:
#      21         city_region_map[city] = region
#      23 print(f"\nFetched regions for {len(city_region_map)} unique cities in {round(time.time() - start_time, 2)} seconds.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:608, in Executor.map.<locals>.result_iterator()
#     605 while fs:
#     606     # Careful not to keep a reference to the popped future
#     607     if timeout is None:
# --> 608         yield fs.pop().result()
#     609     else:
#     610         yield fs.pop().result(end_time - time.monotonic())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:440, in Future.result(self, timeout)
#     437 elif self._state == FINISHED:
#     438     return self.__get_result()
# --> 440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     443     raise CancelledError()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
df_app['Region'] = df_app['Region'].apply(lambda x: None if isinstance(x, str) and x.startswith("No results found") else x)

# %%
df_app['Region'] = df_app['Region'].apply(lambda x: None if isinstance(x, str) and x.startswith("No region found") else x)

# %%
df_app['Region'].value_counts()
# Out:
# Region
# Île-de-France                 21981
# Hauts-de-France               12924
# Auvergne-Rhône-Alpes           9025
# Provence-Alpes-Côte d'Azur     6568
# Occitanie                      6255
# Normandie                      5418
# Grand Est                      5029
# Centre-Val de Loire            3510
# Nouvelle-Aquitaine             3468
# Pays de la Loire               3461
# Bretagne                       2767
# Bourgogne-Franche-Comté        2548
# Aquitaine                       731
# Languedoc-Roussillon            311
# La Réunion                      304
# Maroc                           238
# Tunisie                         182
# Côte d'Ivoire                    75
# Senegal                          66
# France                           59
# Cameroon                         56
# Martinique                       40
# Algerie                          32
# Guadeloupe                       24
# Guyane                           10
# Mayotte                           2
# Corse                             2
# Haute-Normandie                   1
# Name: count, dtype: int64

# %%
# If Mobilite is missing, then we can fill it with the region from the "Region" feature. 
for i in range(len(df_app)):
    if pd.isnull(df_app['Mobilité'][i]) and pd.notnull(df_app['Region'][i]):
        df_app.loc[i, 'Mobilité'] = df_app['Region'][i]

# %%
df_app.shape
# Out:
# (85087, 17)

# %%
df_app.isnull().sum()
# Out:
# Unnamed: 0                                        0
# Id_application                                    0
# Date                                              0
# Id_candidate                                      0
# Id_vacancy                                        0
# Civilité                                      10107
# Ville                                             0
# status                                            0
# Motif de refus                                84087
# Métier                                          439
# Tranche d'age                                 84221
# Type de contrat                               85087
# Prétentions salariales mensuelles fixe net    60252
# Permis de conduire                            56033
# Mobilité                                          0
# Code postal                                    3984
# Region                                            0
# dtype: int64

# %%
#df_app.to_csv('applications_updated.csv')

# %% [markdown]
# ### Merging the three datasets and creating a json dataset for sentence transformers

# %%
merged_df = df_app.merge(df_candidate, on='Id_candidate', how='left')

merged_df = merged_df.merge(df_vac_textual, on='Id_vacancy', how='left')

# %%
merged_df.shape
# Out:
# (85087, 28)

# %%
merged_df.isnull().sum()
# Out:
# Unnamed: 0                                        0
# Id_application                                    0
# Date                                              0
# Id_candidate                                      0
# Id_vacancy                                        0
# Civilité                                      10107
# Ville                                             0
# status                                            0
# Motif de refus                                84087
# Métier                                          439
# Tranche d'age                                 84221
# Type de contrat                               85087
# Prétentions salariales mensuelles fixe net    60252
# Permis de conduire                            56033
# Mobilité                                          0
# Code postal                                    3984
# Region                                            0
# name                                          29128
# fileName                                      29128
# nationality                                   80040
# permis                                        61365
# address                                       36025
# experiences                                   29128
# text                                          29299
# gender                                        43799
# postcode                                      47386
# jobTitle                                      32455
# vacancy_text                                   2479
# dtype: int64

# %%
merged_df.dropna(subset=['text', 'vacancy_text', 'experiences'], inplace=True)
merged_df.shape
# Out:
# (54440, 28)

# %%
# We already have a column for vacancy text. Let's create a column for candidate text combining the text, experiences, and Mobilite columns 

merged_df['candidate_text'] = (
	merged_df['text'].astype(str)
	+ "\nEXPERIENCES:\n"
	+ merged_df['experiences'].astype(str)
	+ "\nMOBILITE:\n"
	+ merged_df['Mobilité'].astype(str)
)

# %%
# Let us see what the raw candidate text looks like:

merged_df['candidate_text'][16]
# Out:
# "DELEPLANQUE Aurele COMPETENCES Capacité d’analyse, d’écoute, de synthèse, autonomie, gestion des priorités Goût du challenge Maitrise du pack office CONTACT 18 rue des ormeaux 59175 Vendeville 06 58 43 34 20 mailto:adeleplanque@live.fr adeleplanque@live.fr SITUATION Née le 03/11/1984 Permis B et véhicule POINTS FORTS Réactive Dynamique Rigoureuse Capacité d’adaptation Gestion du stress INTERETS Voyages Lecture Cuisine ASSISTANTE ADV PARCOURS PROFESSIONNEL SECURIRACKFRANCE–ASSISTANTEADMINISTRATIVEETCO MMERCIALE Depuis septembre 2020 Création de contrats, de devis Gestion administrative du personnel Accueil physique et téléphonique-courriers Préparation à la comptabilité Facturation et relance (clients-fournisseurs) Préparation de salons professionnels Organisation du planning des opérations Réservations des logements lors des chantiers Gestion du stock Gestion des expéditions Organisation et suivi des transports LOXAMA CCE SS-FRETIN–RESPONSABLEDELOCATION/BTOB 2018 – 2020 Contrats clients : offres de prix, édition des factures, gestion des litiges Suivi des chantiers en contact journalier avec les commerciaux terrains pour suivi des offres et évolutions des grilles tarifaires Développement du portefeuille client : prospection, appel d’offre – appels sortants – suivi des plannings de location. KILOUTOU– VI LLENEUVED’ASCQ–ASSISTANTECO MMERCIALE 2015-2018 Réception des appels entrants, établissement des devis et contrats Suivi de facturation, gestion des litiges, relance des impayés clients et fournisseurs Suivi de la logistique, contact des intervenants chantiers, développement du portefeuille client, campagne d’appels sortants. ORANGE BUSINESSSERVICES-MARCQENBAROEUL–GESTIO NNAIRES G R A ND S COMPTES 2010-2015 Réception des appels entrants, établissement des devis et contrats Gestion d’un portefeuille de clients grands comptes - interlocutrice principale pour la gestion du parc mobile, fixe et internet. ETAM LINGERIE - MOUVAUX – PREMIERE VENDEUSE 2005-2010 Début de contrat 15h/semaine (contrat étudiant), puis temps complet Assister la responsable du magasin – conseil client, opérations commerciales, suivi de caisse, comptabilité. Gestion des stocks, réapprovisionnement magasin. FORMATION BTSCO MMUNICATIONDESENTR EPRISES 2006 Lycée privé Saint-Rémi – Roubaix BTS ANIMATION ET GESTION TOURISTIQUES LOCALES 2005 Lycée privé Jeanne d’arc – Aulnoye-Aymeries BA CCALAUREATSCIENCETECHNIQ UETERTIAIRE 2003 Lycée privé Jehanne d’arc - Tourcoing\nEXPERIENCES:\n[{'startDate': '2020-09-01 00:00:00', 'endDate': '2023-01-01 00:00:00', 'jobTitle': 'Not Recognised', 'jobOrg': 'securirackfrance', 'autresInfos': '| création de contrats, de devis gestion administrative du personnel| accueil physique et téléphonique-courriers préparation à la comptabilité| facturation et relance (clients-fournisseurs) préparation de salons professionnels| organisation du planning des opérations| réservations des logements lors des chantiers gestion du stock| gestion des expéditions organisation et suivi des transports| loxama| cce| ss-fretin–responsabledelocation/btob| ', 'escoTitle': '', 'escoScore': -1}, {'startDate': '2018-01-01 00:00:00', 'endDate': '2020-01-01 00:00:00', 'jobTitle': 'gestion des expéditions organisation et suivi des transports', 'jobOrg': 'loxama', 'autresInfos': '| contrats clients : offres de prix, édition des factures, gestion des litiges suivi des chantiers en contact journalier avec les commerciaux terrains pour| suivi des offres et évolutions des grilles tarifaires développement du portefeuille client : prospection, appel d’offre – appels| sortants – suivi des plannings de location.| kiloutou–| lleneuved’ascq–assistanteco| mmerciale| 2015-2018| réception des appels entrants, établissement des devis et contrats suivi de facturation, gestion des litiges, relance des impayés clients et| fournisseurs suivi de la logistique, contact des intervenants chantiers, développement du| portefeuille client, campagne d’appels sortants.| orange| businessserv ...

# %%
# Cleaning the candidate text by removing unncessary information like email Id and phone numbers

import re

def clean_text(text):
    if pd.isnull(text):
        return text
    
    # Remove email addresses
    text = re.sub(r'\b[\w.-]+?@\w+?\.\w+?\b', '', text)
    
    # Remove phone numbers (various formats)
    text = re.sub(r'\b(?:\+?\d{1,3}[-.\s]?)?(?:\(?\d{2,4}\)?[-.\s]?)?\d{3,5}[-.\s]?\d{3,5}\b', '', text)
    
    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# Apply the function to the column
merged_df['candidate_text'] = merged_df['candidate_text'].apply(clean_text)

# %%
merged_df['candidate_text'][16]
# Out:
# "DELEPLANQUE Aurele COMPETENCES Capacité d’analyse, d’écoute, de synthèse, autonomie, gestion des priorités Goût du challenge Maitrise du pack office CONTACT 18 rue des ormeaux 59175 Vendeville 06 58 43 34 20 mailto: SITUATION Née le 03/11/1984 Permis B et véhicule POINTS FORTS Réactive Dynamique Rigoureuse Capacité d’adaptation Gestion du stress INTERETS Voyages Lecture Cuisine ASSISTANTE ADV PARCOURS PROFESSIONNEL SECURIRACKFRANCE–ASSISTANTEADMINISTRATIVEETCO MMERCIALE Depuis septembre 2020 Création de contrats, de devis Gestion administrative du personnel Accueil physique et téléphonique-courriers Préparation à la comptabilité Facturation et relance (clients-fournisseurs) Préparation de salons professionnels Organisation du planning des opérations Réservations des logements lors des chantiers Gestion du stock Gestion des expéditions Organisation et suivi des transports LOXAMA CCE SS-FRETIN–RESPONSABLEDELOCATION/BTOB 2018 – 2020 Contrats clients : offres de prix, édition des factures, gestion des litiges Suivi des chantiers en contact journalier avec les commerciaux terrains pour suivi des offres et évolutions des grilles tarifaires Développement du portefeuille client : prospection, appel d’offre – appels sortants – suivi des plannings de location. KILOUTOU– VI LLENEUVED’ASCQ–ASSISTANTECO MMERCIALE Réception des appels entrants, établissement des devis et contrats Suivi de facturation, gestion des litiges, relance des impayés clients et fournisseurs Suivi de la logistique, contact des intervenants chantiers, développement du portefeuille client, campagne d’appels sortants. ORANGE BUSINESSSERVICES-MARCQENBAROEUL–GESTIO NNAIRES G R A ND S COMPTES Réception des appels entrants, établissement des devis et contrats Gestion d’un portefeuille de clients grands comptes - interlocutrice principale pour la gestion du parc mobile, fixe et internet. ETAM LINGERIE - MOUVAUX – PREMIERE VENDEUSE Début de contrat 15h/semaine (contrat étudiant), puis temps complet Assister la responsable du magasin – conseil client, opérations commerciales, suivi de caisse, comptabilité. Gestion des stocks, réapprovisionnement magasin. FORMATION BTSCO MMUNICATIONDESENTR EPRISES 2006 Lycée privé Saint-Rémi – Roubaix BTS ANIMATION ET GESTION TOURISTIQUES LOCALES 2005 Lycée privé Jeanne d’arc – Aulnoye-Aymeries BA CCALAUREATSCIENCETECHNIQ UETERTIAIRE 2003 Lycée privé Jehanne d’arc - Tourcoing EXPERIENCES: [{'startDate': '2020-09-01 00:00:00', 'endDate': '2023-01-01 00:00:00', 'jobTitle': 'Not Recognised', 'jobOrg': 'securirackfrance', 'autresInfos': '| création de contrats, de devis gestion administrative du personnel| accueil physique et téléphonique-courriers préparation à la comptabilité| facturation et relance (clients-fournisseurs) préparation de salons professionnels| organisation du planning des opérations| réservations des logements lors des chantiers gestion du stock| gestion des expéditions organisation et suivi des transports| loxama| cce| ss-fretin–responsabledelocation/btob| ', 'escoTitle': '', 'escoScore': -1}, {'startDate': '2018-01-01 00:00:00', 'endDate': '2020-01-01 00:00:00', 'jobTitle': 'gestion des expéditions organisation et suivi des transports', 'jobOrg': 'loxama', 'autresInfos': '| contrats clients : offres de prix, édition des factures, gestion des litiges suivi des chantiers en contact journalier avec les commerciaux terrains pour| suivi des offres et évolutions des grilles tarifaires développement du portefeuille client : prospection, appel d’offre – appels| sortants – suivi des plannings de location.| kiloutou–| lleneuved’ascq–assistanteco| mmerciale| | réception des appels entrants, établissement des devis et contrats suivi de facturation, gestion des litiges, relance des impayés clients et| fournisseurs suivi de la logistique, contact des intervenants chantiers, développement du| portefeuille client, campagne d’appels sortants.| orange| businessservices-marcqenbaroeul–gestio| nnaires g r a nd| comptes| | réception des appels entr ...

# %% [markdown]
# ### Assigning labels

# %%
status_1 = {'Embauche'}

status_2 = {'NAE', 'NAE +5jrs', 'NAE Vivier'}

status_3 = {'NET', 'NET+ 3jrs', 'NET Savoir Etre', 'NET Rému', 'NET Cond. Travail', 'NET Localisation',
                'NET Savoir Faire'}

status_4 = {'Négatif', 'Négatif + 2jrs', 'Négatif + 5jrs', 'Neg sans msg'}

other = {'Vivier', 'Vivier + 2jrs', 'No news', 'Poste pourvu'}

for i in merged_df.index:
    if merged_df.loc[i, 'status'] in status_1:
        merged_df.loc[i, 'label'] = 1
    elif merged_df.loc[i, 'status'] in other:
        merged_df.loc[i, 'label'] = None
    else:
        merged_df.loc[i, 'label'] = 0

# %%
merged_df.shape
# Out:
# (54440, 30)

# %%
merged_df['label'].value_counts()
# Out:
# label
# 0.0    34720
# 1.0      417
# Name: count, dtype: int64

# %%
merged_df['label'].isnull().sum()
# Out:
# 19303

# %% [markdown]
# ### Converting to json for the sentence transformers

# %%
# We need the following columns for this: 'vacancy_text', 'candidate_text', 'Civilite', 'label'. 
# First, recheck for missing values in any of these columns

merged_df.isnull().sum()
# Out:
# Unnamed: 0                                        0
# Id_application                                    0
# Date                                              0
# Id_candidate                                      0
# Id_vacancy                                        0
# Civilité                                       6367
# Ville                                             0
# status                                            0
# Motif de refus                                53454
# Métier                                           17
# Tranche d'age                                 54035
# Type de contrat                               54440
# Prétentions salariales mensuelles fixe net    39649
# Permis de conduire                            38450
# Mobilité                                          0
# Code postal                                    2452
# Region                                            0
# name                                              0
# fileName                                          0
# nationality                                   49528
# permis                                        31321
# address                                        6710
# experiences                                       0
# text                                              0
# gender                                        14316
# postcode                                      17661
# jobTitle                                       3074
# vacancy_text                                      0
# candidate_text                                    0
# label                                         19303
# dtype: int64

# %%
# Still some missing values in Civilite, delete them. 

merged_df = merged_df.dropna(subset=['Civilité'])

# %%
merged_df.shape
# Out:
# (46279, 29)

# %%
merged_df['Civilité'].value_counts()

# Distribution of gender
# Out:
# Civilité
# Monsieur    34416
# Madame      11863
# Name: count, dtype: int64

# %%
# Distribution of labels

merged_df['label'].value_counts()
# Out:
# label
# 0    28576
# 1    17703
# Name: count, dtype: int64

# %%
# Label versus gender

pd.crosstab(merged_df['label'], merged_df['Civilité'])
# Out:
# Civilité  Madame  Monsieur
# label
# 0           7734     20842
# 1           4129     13574

# %%
# Mapping gender to a number 

def map_gender_to_number(gender):
    if gender == 'Madame':
        return 1
    elif gender == 'Monsieur':
        return 0

merged_df['gender_number'] = merged_df['Civilité'].apply(map_gender_to_number)

# %%
#merged_df.to_csv('new_everything_dataset.csv')

# %%
df_renamed = merged_df[['candidate_text', 'vacancy_text', 'gender_number', 'label']].rename(columns={
    'candidate_text': 'sentence1',
    'vacancy_text': 'sentence2'
})

df_renamed.head()
# Out:
#                                              sentence1  \
# 16   DELEPLANQUE Aurele COMPETENCES Capacité d’anal...
# 50   ALBICE Yohann 2 rue d'Alembert 93000 BOBIGNY 2...
# 55   Jeremy Philétas Electromécanicien Ozoir-la-Fer...
# 234  CONDUCTEUR DÉMONSTRATEUR PL CONTACT 553 CHEMIN...
# 299  Fabrice Tallon Neuilly-sous-Clermont (60) 6060...
#
#                                              sentence2  gender_number  label
# 16   Titre: Chargé de relation Clientèle (H/F) - Ma...              1      1
# 50   Titre: Mécanicien spécialisé (H/F) - Gennevill...              0      1
# 55   Titre: Electro-mécanicien (H/F) - Croissy Beau...              0      1
# 234  Titre: Conducteur VL (H/F) - Lyon Sud\nFonctio...              0      1
# 299  Titre: Mécanicien Spécialisé (H/F) - Saint Max...              0      1

# %%
df_renamed.shape
# Out:
# (46279, 4)

# %%
# Convert to list of dictionaries
json_data = df_renamed.to_dict(orient='records')

# Save to JSON file
with open('data_made_with_raw_cv_text.json', 'w', encoding='utf-8') as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Part 2: Make updates to the CV text with language models

# %%
df = pd.read_csv('new_everything_dataset.csv')
df.shape
# Out:
# C:\Users\Sinjini\AppData\Local\Temp\ipykernel_11716\1639956706.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('new_everything_dataset.csv')
# (54440, 31)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Id_application', 'Date', 'Id_candidate',
#        'Id_vacancy', 'Civilité', 'Ville', 'status', 'Motif de refus', 'Métier',
#        'Tranche d'age', 'Type de contrat',
#        'Prétentions salariales mensuelles fixe net', 'Permis de conduire',
#        'Mobilité', 'Code postal', 'Region', 'name', 'fileName', 'nationality',
#        'permis', 'address', 'experiences', 'text', 'gender', 'postcode',
#        'jobTitle', 'vacancy_text', 'candidate_text', 'label'],
#       dtype='object')

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
import pandas as pd
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

template = """
Extrayez les champs structurés suivants du profil du candidat :

- Intitulé du poste actuel
- Intitulés des postes précédents
- Formation
- Compétences
- Secteurs d'activité des entreprises précédentes

Soyez concis et concentrez-vous uniquement sur les mots-clés. Voice le profil: 


{messy_text}
"""

prompt = ChatPromptTemplate.from_template(template)
model = OllamaLLM(model="phi4-mini", temperature=0)
chain = prompt | model

start = time.time()
updates = 0

def process_row(i):
    try:
        messy_text = str(df.loc[i, 'candidate_text'])
        mobility = str(df.loc[i, 'Mobilité'])
        messy_text += f"\nMobilité/Lieu de travail souhaité: {mobility}"

        result = chain.invoke({"messy_text": messy_text})
        print(f"Row {i} update:\n{result}\n{'-'*40}")
        return i, result
    except Exception as e:
        print(f"Error at row {i}: {e}")
    return i, None

# Use multithreading
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = [executor.submit(process_row, i) for i in range(len(df))]
    
    for future in as_completed(futures):
        i, result = future.result()
        if result:
            df.loc[i, 'candidate_text_llm'] = result
            updates += 1
            print(f"Updated row {i}. Total updates so far: {updates}")

#df.to_csv("new_everything_llm.csv", index=False)
print(f"Finished updating {updates} rows in {time.time() - start:.2f} seconds.")

# %%
df1 = pd.read_csv('new_everything_llm.csv')
# Out:
# C:\Users\Sinjini\AppData\Local\Temp\ipykernel_22624\950053154.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('new_everything_llm.csv')

# %%
df1.shape
# Out:
# (43768, 33)

# %%
df1['Civilité'].value_counts()
# Out:
# Civilité
# Monsieur    32523
# Madame      11245
# Name: count, dtype: int64

# %%
df1['label'].value_counts()
# Out:
# label
# 0    27044
# 1    16724
# Name: count, dtype: int64

# %%
pd.crosstab(df1['label'], df1['Civilité'])
# Out:
# Civilité  Madame  Monsieur
# label
# 0           7329     19715
# 1           3916     12808

# %%
df_renamed = df1[['structured_profile', 'vacancy_text', 'gender_number', 'label']].rename(columns={
    'structured_profile': 'sentence1',
    'vacancy_text': 'sentence2'
})

df_renamed.head()
# Out:
#                                            sentence1  \
# 0  :\n\n- **Intitulé du poste actuel** : Assistan...
# 1  :\n\n- **Intitulé du poste actuel** : Ouvrier\...
# 2  **Current Title**: septembre\n**Previous Roles...
# 3  :\n\n- **Intitulé du poste actuel** : Conducte...
# 4  **Current Title**: technicien de maintenance\n...
#
#                                            sentence2  gender_number  label
# 0  Titre: Chargé de relation Clientèle (H/F) - Ma...              1      1
# 1  Titre: Mécanicien spécialisé (H/F) - Gennevill...              0      1
# 2  Titre: Electro-mécanicien (H/F) - Croissy Beau...              0      1
# 3  Titre: Conducteur VL (H/F) - Lyon Sud\nFonctio...              0      1
# 4  Titre: Mécanicien Spécialisé (H/F) - Saint Max...              0      1

# %%
df_renamed['sentence1'] = df_renamed['sentence1'].str.replace(':\n\n', '')
df_renamed['sentence1'] = df_renamed['sentence1'].str.replace('-**', '')
df_renamed['sentence1'] = df_renamed['sentence1'].str.replace('**', '')
df_renamed['sentence1'] = df_renamed['sentence1'].str.replace('-', '')

# %%
# Convert to list of dictionaries
json_data = df_renamed.to_dict(orient='records')

# Save to JSON file
with open('data_with_llm_cv_text.json', 'w', encoding='utf-8') as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Part 3: Creating sentence pairs with ESCO titles
# (This dataset was not used for evaluation or training. A better dataset with ESO titles was created later).

# %%
df = pd.read_csv("new_everything_dataset.csv")

# %%
df['experiences'][0]

# %%
import ast

def extract_non_blank_esco_titles_ast(experiences_str):
    """
    Extracts non-blank 'escoTitle' values from a string representation of a list of dictionaries
    using ast.literal_eval to handle potentially non-strict JSON.

    Args:
        experiences_str: A string representing a list of dictionaries, where each
                         dictionary contains job experience information, including
                         'escoTitle'.

    Returns:
        A list of non-blank 'escoTitle' strings found in the input.
    """
    try:
        experiences_list = ast.literal_eval(experiences_str)
        esco_titles = [exp['escoTitle'] for exp in experiences_list if isinstance(exp, dict) and exp.get('escoTitle')]
        return esco_titles
    except (SyntaxError, ValueError):
        print(f"Error decoding string with ast.literal_eval: {experiences_str}")
        return []

# Apply the corrected function to the 'experiences' column
df['esco_titles'] = df['experiences'].apply(extract_non_blank_esco_titles_ast)

# You can still explode the DataFrame if needed
df_exploded = df.explode('esco_titles')
print(df_exploded[['jobTitle', 'esco_titles']].head())

# %%
# Calculate the number of rows where 'esco_titles' is an empty list
num_blank_esco_titles = df['esco_titles'].apply(lambda x: len(x) == 0).sum()

# Print the result
print(f"Number of blank esco_titles: {num_blank_esco_titles}")

# %%
count = 0
for i in range(len(df['esco_titles'])):
    if len(df['esco_titles'][i]) == 0 or not isinstance(df['esco_titles'][i], list) or df['esco_titles'][i] == []:
        count += 1
        #print(i)

print(count)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

esco_df = pd.read_csv("occupations_fr.csv")

model = SentenceTransformer('distiluse-base-multilingual-cased')  # Supports French

# Encode ESCO titles
esco_embeddings = model.encode(esco_df['description'].tolist(), convert_to_tensor=True)

def get_best_esco_title(text):
    text_embedding = model.encode(text, convert_to_tensor=True)
    similarities = cosine_similarity([text_embedding], esco_embeddings)[0]
    best_match_idx = similarities.argmax()
    return str(esco_df.iloc[best_match_idx]['preferredLabel']) + str(esco_df.iloc[best_match_idx]['altLabels'])

# Apply to your dataframe
#df['esco_title_vacancy'] = df['vacancy_text'].apply(get_best_esco_title)

# %%
for element in df['vacancy_text'][:1]:
    print(get_best_esco_title(element))

# %%
get_best_esco_title(df['vacancy_text'][0])

# %%
# Apply to your dataframe
df['esco_title_vacancy'] = df['vacancy_text'].apply(get_best_esco_title)

# %%
df.to_csv('new_everything_esco.csv')

# %%
df = pd.read_csv("new_everything_esco.csv")

# %%
df.rename(columns={'esco_titles': 'esco_titles_candidate'}, inplace=True)

# %%
#How many rows have empty esco_titles_candidate?
df['esco_titles_candidate'][df['esco_titles_candidate'].isnull() | (df['esco_titles_candidate'] == '[]')].shape[0]

# %%
# How many rows have empty esco_titles_vacancy?
df['esco_title_vacancy'][df['esco_title_vacancy'].isnull() | (df['esco_title_vacancy'] == '[]') | (df['esco_title_vacancy'] == '')].shape[0]

# %%
# Delete the rows with empty esco_titles_candidate

df = df[~(df['esco_titles_candidate'].isnull() | (df['esco_titles_candidate'] == '[]'))]

# %%
df['esco_titles_candidate'] = df['esco_titles_candidate'].str.replace('[', '')
df['esco_titles_candidate'] = df['esco_titles_candidate'].str.replace(']', '')
df['esco_titles_candidate'] = df['esco_titles_candidate'].str.replace("'", '')

# %%
df_renamed = df[['esco_titles_candidate', 'esco_title_vacancy', 'gender_number', 'label']].rename(columns={
    'esco_titles_candidate': 'sentence1',
    'esco_title_vacancy': 'sentence2'
})

df_renamed.head()

# %%
# Convert to list of dictionaries
json_data = df_renamed.to_dict(orient='records')

# Save to JSON file
with open('data_with_esco_titles.json', 'w', encoding='utf-8') as f:
    json.dump(json_data, f, ensure_ascii=False, indent=4)
